# %% [markdown]
# **Proyecto:** INE Incidentes de Transito.
#
# **Objetivo:** Creacion de catalogos, esquemas y tablas para bronze.
#
# **Dependencias / Librerias:** Storage Credential y External Location
#
# **Ambiente de Ejecución:** Databricks, Desarrollo
#
# ---
# | Fecha | Desarrollador | Descripcion |
# | :--- | :--- | :--- |
# | 03/NOV/2025 | Ruben Coloma | Emision Inicial |

# %% [markdown]
# **CATALOGO**

# %%
# %sql
--DROP CATALOG IF EXISTS cat_ine_trafico_dev CASCADE

# %%
# %sql
CREATE CATALOG cat_ine_trafico_dev

# %% [markdown]
# **ESQUEMAS**

# %%
# %sql
-- Schema Bronze
CREATE SCHEMA cat_ine_trafico_dev.bronze_ine_trafico_dev
MANAGED LOCATION 'abfss://bronze@stinetraficodeveastus2.dfs.core.windows.net/';

-- Schema Silver
CREATE SCHEMA cat_ine_trafico_dev.silver_ine_trafico_dev
MANAGED LOCATION 'abfss://silver@stinetraficodeveastus2.dfs.core.windows.net/';

-- Schema Gold
CREATE SCHEMA cat_ine_trafico_dev.gold_ine_trafico_dev
MANAGED LOCATION 'abfss://gold@stinetraficodeveastus2.dfs.core.windows.net/';

# %%
# %sql
--DROP SCHEMA IF EXISTS cat_ine_trafico_dev.lesionados;
--DROP SCHEMA IF EXISTS cat_ine_trafico_dev.fallecidos;
--DROP SCHEMA IF EXISTS cat_ine_trafico_dev.vehiculos;

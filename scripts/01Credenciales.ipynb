# %% [markdown]
# **Proyecto:** INE Incidentes de Transito.
#
# **Objetivo:** Creacion de External Location a Bronze, Silver y Gold.
#
# **Dependencias / Librerias:** Storage Credential 'strcred_ine_trafico_dev'
#
# **Ambiente de Ejecución:** Databricks, Azure, Desarrollo
#
# ---
# | Fecha | Desarrollador | Descripcion |
# | :--- | :--- | :--- |
# | 03/NOV/20025 | Ruben Coloma | Emision Inicial |

# %% [markdown]
# **EXTERNAL LOCATION**

# %%
# %sql
-- Contenedor BRONZE
CREATE EXTERNAL LOCATION extloc_ine_trafico_dev_bronze
URL 'abfss://bronze@stinetraficodeveastus2.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL strcred_ine_trafico_dev)
COMMENT 'External Location del contenedor Bronze - Proyecto INE Trafico (Dev)';

# %%
# %sql
-- Contenedor SILVER
CREATE EXTERNAL LOCATION extloc_ine_trafico_dev_silver
URL 'abfss://silver@stinetraficodeveastus2.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL strcred_ine_trafico_dev)
COMMENT 'External Location del contenedor Silver - Proyecto INE Trafico (Dev)';

# %%
# %sql
-- Contenedor GOLD
CREATE EXTERNAL LOCATION extloc_ine_trafico_dev_gold
URL 'abfss://gold@stinetraficodeveastus2.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL strcred_ine_trafico_dev)
COMMENT 'External Location del contenedor Gold - Proyecto INE Trafico (Dev)';

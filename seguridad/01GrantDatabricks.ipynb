# %% [markdown]
# **Proyecto:** INE Incidentes de Transito.
#
# **Objetivo:** Otogar prermisos para crear: Storage Credential, External Location y Catalog.
#
# **Dependencias / Librerias:** Usuario administrador de Databricks.
#
# **Ambiente de Ejecución:** Consola de Administracion de Databricks.
#
# ---
# | Fecha | Desarrollador | Descripcion |
# | :--- | :--- | :--- |
# | 03/NOV/2025 | Ruben Coloma | Emision Inicial |

# %%
# %sql
-- Permitir crear Storage Credentials
GRANT CREATE STORAGE CREDENTIAL ON METASTORE TO `coloma.ruben@gmail.com`;

# %%
# %sql
-- Permitir crear External Location
GRANT CREATE EXTERNAL LOCATION ON METASTORE TO `coloma.ruben@gmail.com`;

# %%
# %sql
-- Permitir crear Catalogos
GRANT CREATE CATALOG ON METASTORE TO `coloma.ruben@gmail.com`;

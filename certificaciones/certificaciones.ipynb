# %% [markdown]
# **Proyecto:** INE Incidentes de Transito.
#
# **Academia**: SmartData
#
# **Objetivo:** Lista de certificaciones.
#
# **Dependencias / Librerias:** No aplica.
#
# **Ambiente de Ejecución:** No aplica.
#
# ---
# | Fecha | Desarrollador | Descripcion |
# | :--- | :--- | :--- |
# | 07/NOV/20025 | Ruben Coloma | Emision Inicial |

# %% [markdown]
# ## Databricks Fundamentals
# [https://credentials.databricks.com/a333c320-bbc3-48f0-a5e6-fa60e5fe13b6#acc.apNYf84g](https://credentials.databricks.com/a333c320-bbc3-48f0-a5e6-fa60e5fe13b6#acc.apNYf84g)

# %% [markdown]
# ## Databricks - Generative AI Fundamentals
# [https://credentials.databricks.com/429d72ff-f8d3-4f6b-a79d-872eaca4dd79#acc.ShMZN3U8](https://credentials.databricks.com/429d72ff-f8d3-4f6b-a79d-872eaca4dd79#acc.ShMZN3U8)
